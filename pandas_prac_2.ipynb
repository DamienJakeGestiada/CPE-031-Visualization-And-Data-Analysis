# %% [markdown]
# <a href="https://colab.research.google.com/github/DamienJakeGestiada/CPE-031-Visualization-And-Data-Analysis/blob/main/pandas_prac_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {

'apple':[3,2,0,1],
'orange':[0,3,7,2]

}

purchases = pd.DataFrame(data)
purchases
# Out:
#    apple  orange
# 0      3       0
# 1      2       3
# 2      0       7
# 3      1       2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# purchases['apple'].plot(kind='hist', bins=20, title='apple')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# purchases['orange'].plot(kind='hist', bins=20, title='orange')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# purchases.plot(kind='scatter', x='apple', y='orange', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
import pandas as pd

data = {

'apple':[3,2,0,1],
'orange':[0,3,7,2]

}

purchases = pd.DataFrame(data, index=['june','robert','lily','david'])
purchases
# Out:
#         apple  orange
# june        3       0
# robert      2       3
# lily        0       7
# david       1       2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# purchases['apple'].plot(kind='hist', bins=20, title='apple')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# purchases['orange'].plot(kind='hist', bins=20, title='orange')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# purchases.plot(kind='scatter', x='apple', y='orange', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
purchases.loc ['june'] #locate
# Out:
# apple     3
# orange    0
# Name: june, dtype: int64

# %%
purchases.to_csv('fruit.csv')

# %%
#from google.colab import drive
#drive.mount('/content/drive')

df = pd.read_csv("/content/drive/MyDrive/CPE_031_Gestiada/RoadAccidents.csv")
# Out:
# Mounted at /content/drive
