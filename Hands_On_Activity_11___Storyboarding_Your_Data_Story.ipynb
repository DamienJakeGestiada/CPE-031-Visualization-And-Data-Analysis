# %% [markdown]
# <a href="https://colab.research.google.com/github/DamienJakeGestiada/CPE-031-Visualization-And-Data-Analysis/blob/main/Hands_On_Activity_11___Storyboarding_Your_Data_Story.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 11 | Storyboarding Your Data Story**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Damien Jake D. Gestiada and Christopher Fegalan<br>
# Course Code and Title : CPE 031/Visualizations and Data Analysis<br>
# Date Submitted : 06/11/2025<br>
# Instructor : Maria Rizette Sayo <br>
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate the ability to plan and visualize a simple data story using a storyboard approach, combining storytelling elements with visual thinking before coding full visualizations.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze a dataset and identify the key message or insight.
#
# 2. Organize a logical flow for storytelling using a storyboard structure.
#
# 3. Create a simple storyboard visualization in Python.

# %% [markdown]
# **3. Discussions:**
#
# Storyboarding helps plan how your data story will unfold just like scenes in a movie.
# It helps you decide what charts, annotations, or visuals are needed to communicate your message effectively.
#
# A typical storyboard has:
#
# Frame 1: Title or question (What are we exploring?)
#
# Frame 2: Key data visualization or comparison
#
# Frame 3: Main insight or conclusion
#
# In Python, you can simulate a storyboard using multiple subplots each representing a scene or frame in your story.

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Storyboard Example – “Sales Growth Over Time”

# %%
# Import libraries
import matplotlib.pyplot as plt

# Sample data
years = [2020, 2021, 2022, 2023, 2024]
sales = [100, 150, 200, 300, 450]

# Create storyboard using subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Frame 1: Title / Introduction
axes[0].text(0.5, 0.5, "Our Sales Journey\n(2020–2024)", ha='center', va='center', fontsize=14)
axes[0].axis("off")

# Frame 2: Key Data Visualization
axes[1].plot(years, sales, marker='o', color='steelblue')
axes[1].set_title("Sales Over Time")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Sales (in units)")

# Frame 3: Insight / Message
axes[2].text(0.5, 0.5, "Insight:\nSales grew steadily,\nwith a big jump after 2022!",
             ha='center', va='center', fontsize=12, color='darkgreen')
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Choose a small dataset (e.g., from Kaggle or manually created).
# Then, create a 3-frame storyboard in Python showing:
#
# Frame 1: Title or question
#
# Frame 2: One simple chart (bar or line)
#
# Frame 3: Main message or conclusion
#
# 2. Use matplotlib and label each part clearly.

# %%
#Code here

import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
visitors = [120, 150, 180, 220, 260, 310]

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].text(0.5, 0.5, "How Did Our Website Traffic Grow\nin the First Half of 2024?",
             ha='center', va='center', fontsize=12)
axes[0].axis("off")

axes[1].bar(months, visitors, color='skyblue')
axes[1].set_title("Monthly Website Visitors")
axes[1].set_xlabel("Month")
axes[1].set_ylabel("Number of Visitors")

axes[2].text(0.5, 0.5, "Insight:\nTraffic steadily increased,\nshowing strong growth after March.",
             ha='center', va='center', fontsize=11, color='green')
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# *Type it here
#
# Analysis
#
# - The dataset of monthly website traffic from January to June 2024 was displayed using a 3-frame storyboard. The first frame raised the subject of traffic increase, and the second frame employed a bar chart to show a consistent upward trend. The visualization revealed a significant rise in visitors, especially in March, showing greater web reach or effective promotional efforts during that time. The final frame effectively expressed this finding as a clear insight, showing how storyboarding connects data trends with interpretation before producing complete visualizations.
#
# Conclusion and Learning:
#
# - We learnt how to use storyboards to organize and visualize data in an organized storytelling style.  This activity recognized the importance of arranging words and images to improve data communication accuracy and engagement.  By using Python's Matplotlib to build storyboard frames, we discovered that even simple charts, when organized rationally, may tell an entire story, from the beginning to end. This task increased our knowledge that data visualization is more than just making graphs, but it is also about developing engaging stories that effectively bring the audience to ideas.
